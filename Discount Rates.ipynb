# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Discount-Rates" data-toc-modified-id="Discount-Rates-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Discount Rates</a></span></li><li><span><a href="#Import-libraries" data-toc-modified-id="Import-libraries-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Import libraries</a></span></li></ul></div>

# %% [markdown]
# # Discount Rates

# %% [markdown]
# Discount rates are used to calculate the net present value of any future or past value. They are thus used to compare amounts paid (costs) and received (benefits) in different years. A project is economically viable (attractive), if the net present value of benefits exceeds the net present value of costs - a cost-benefit ratio < 1.
#
# There are several important implications that come along with discount rates. Namely, that higher discount rates lead to smaller net present values of future impacts (costs). As a consequence of that, climate action and mitigation measures can be postboned. In the literature higher discount rates are typically justified by the expectation of continued exponential growth of the economy. The most widley used interest rate in climate change economics is 1.4% as propsed by the Stern Review (2006). Neoliberal economists around Nordhaus (2007) claim that rates should be higher, around 4.3%. Environmental economists argue that future costs shouldn’t be discounted at all. This is especially true for non-monetary variables such as ecosystems or human lifes, where no price tag should be applied out of ethical reasons. This discussion has a long history, reaching back to the 18th century: “Some things have a price, or relative worth, while other things have a dignity, or inner worth” (Kant, 1785).

# %% [markdown]
# The numpy-financial package contains a collection of elementary financial functions. For this exercise we will be using the .npv() function to calculate what is the dollar amount that needs to be paid now to address a impact/damage in the future.

# %%
# Uncomment the line below and run this cell to install the numpy-financial package
# ! pip install numpy-financial

# %% [markdown]
# # Import libraries

# %%
import numpy_financial as npf
import matplotlib.pyplot as plt

# %% [markdown]
# Let's calculate the net present value of future cost (5-years) of 100 dollars

# %%
npf.npv(0.05, [0,0,0,0,100])
# Out:
# 82.27024747918819

# %% [markdown]
# Let's plot a graph showing the relationship between time and net present value with discount rate of 4.3%

# %%
# Initiate a list that will store the net present values
npv = []
# Calculate the net present values for future 100 years with discount rate=4.3%
for i in range(1,101):
    npv.append(npf.npv(0.043, [0] * (i-1) + [100]))

# %%
# Check the length of the list
len(npv)
# Out:
# 100

# %%
# Set the resolution and figure size
plt.figure(dpi=300, figsize=(30,15))

# Line plot with matplotlib
plt.plot([i for i in range(1,101)] , npv,
         marker='o', linewidth=2, color='k')

# Format the ticks for horizontal and vertical axes
plt.xticks(np.arange(0, 110, step=10), fontsize=20);
plt.yticks(np.arange(0, 110, step=10), fontsize=20);

# Add figure title and create labels for horizontal and vertical axes
plt.xlabel('Year', fontsize=30, labelpad=10)
plt.ylabel('Net Present Value ($)', fontsize=30, labelpad=10)
plt.title('Relationship between time and net present value (discount rate=4.3%)', fontsize=35)

# Show grid
plt.grid(True, color='lightgrey', linestyle='--', linewidth=1, zorder=0)
